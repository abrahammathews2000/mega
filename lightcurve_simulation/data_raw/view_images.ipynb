# %%
# %matplotlib inline
#The line above is necesary to show Matplotlib's plots inside a Jupyter Notebook

import cv2
from matplotlib import pyplot as plt

#Import image
link = '../../data_raw/shape/3/2099.png'

image = cv2.imread(link)

#Show the image with matplotlib
plt.imshow(image)
plt.show()

# %%
#Import image
link = '../../data_raw/shape/3/h_16000.png'

image = cv2.imread(link)

#Show the image with matplotlib
plt.imshow(image)
plt.show()

# %%
#Import image
link = '../../data_raw/shape/3/h_ra_2099.png'

image = cv2.imread(link)

#Show the image with matplotlib
plt.imshow(image)
plt.show()

# %%
#Import image
link = '../../data_raw/shape/3/ra_2099.png'

image = cv2.imread(link)

#Show the image with matplotlib
plt.imshow(image)
plt.show()
